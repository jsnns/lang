# %%
import matplotlib.pyplot as plt

# %%
plt.plot([entry["Networth"] for entry in entries])

# %%
import pandas as pd

# %%
df = pd.DataFrame(entries)
df
# Out:
#     Networth                   Car                   City  \
# 0    20000.0               Audi S3            Danbury, CT
# 1    20000.0               Audi S3            Danbury, CT
# 2    20000.0               Audi S3            Danbury, CT
# 3    23100.0     None, bike / walk            Danbury, CT
# 4    24300.0     None, bike / walk             Danbury CT
# 5    23600.0  Chevy Volt (Tyler's)                Danbury
# 6    24500.0  Chevy Volt (Tyler's)                Danbury
# 7    27300.0                  None            Danbury, CT
# 8    26300.0    Tyler's Chevy Volt            Danbury, CT
# 9    17883.0    2014 Jaguar F-TYPE              Daly City
# 10   20600.0         Jaguar F-TYPE          San Francisco
# 11   20007.0    2014 Jaguar F-TYPE  Daly City (Garden Ln)
# 12   32000.0    2014 Jaguar F-TYPE              Daly City
# 13   31000.0    2014 Jaguar F-TYPE          Daly City, CA
# 14   25913.0         Jaguar F-TYPE          San Francisco
# ...
